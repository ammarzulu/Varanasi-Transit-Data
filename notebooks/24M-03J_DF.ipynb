# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../data/drive-download-20230607T151956Z-001/24052023_OD_demand.csv')
df2 = pd.read_csv('../data/drive-download-20230607T151956Z-001/25052023_OD_demand.csv')
df3 = pd.read_csv('../data/drive-download-20230607T151956Z-001/26052023_OD_demand.csv')
df4 = pd.read_csv('../data/drive-download-20230607T151956Z-001/27052023_OD_demand.csv')
df5 = pd.read_csv('../data/drive-download-20230607T151956Z-001/28052023_OD_demand.csv')
df6 = pd.read_csv('../data/drive-download-20230607T151956Z-001/29052023_OD_demand.csv')
df7 = pd.read_csv('../data/drive-download-20230607T151956Z-001/30052023_OD_demand.csv')
df8 = pd.read_csv('../data/drive-download-20230607T151956Z-001/31052023_OD_demand.csv')
df9 = pd.read_csv('../data/drive-download-20230607T151956Z-001/01062023_OD_demand.csv')
df10= pd.read_csv('../data/drive-download-20230607T151956Z-001/02062023_OD_demand.csv')
df11= pd.read_csv('../data/drive-download-20230607T151956Z-001/03062023_OD_demand.csv')

# %%
df1['dates'] = pd.Timestamp('2023-05-24')

# %%
df1
# Out:
#       Unnamed: 0                     R.N       FROM                    TO  \
# 0              1                     107     ASAPUR     CANTT RLY STATION
# 1              2                     107     ASAPUR  CANTT RLY\r\nSTATION
# 2              3                     107     ASAPUR            DURGA KUND
# 3              4                     107     ASAPUR                 LANKA
# 4              5                     107     ASAPUR           POLICE LINE
# ...          ...                     ...        ...                   ...
# 1841        1842  Route No.\r\n(E105) FG  SAHABABAD              CHOLAPUR
# 1842        1843  Route No.\r\n(E105) FG  SAHABABAD               KHAJURI
# 1843        1844  Route No.\r\n(E105) FG  SAHABABAD              MODHAILA
# 1844        1845  Route No.\r\n(E105) FG  SAHABABAD            MOHANSARAI
# 1845        1846  Route No.\r\n(E105) FG  SAHABABAD             PANDEYPUR
#
#       prs  revenue      dates
# 0       3       66 2023-05-24
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0             int64
# R.N                   object
# FROM                  object
# TO                    object
# prs                    int64
# revenue                int64
# dates         datetime64[ns]
# dtype: object

# %%
df2['dates'] = pd.Timestamp('2023-05-25') 
df3['dates'] = pd.Timestamp('2023-05-26') 
df4['dates'] = pd.Timestamp('2023-05-27') 
df5['dates'] = pd.Timestamp('2023-05-28') 
df6['dates'] = pd.Timestamp('2023-05-29') 
df7['dates'] = pd.Timestamp('2023-05-30') 
df8['dates'] = pd.Timestamp('2023-05-31') 
df9['dates'] = pd.Timestamp('2023-06-01') 
df10['dates'] = pd.Timestamp('2023-06-02') 
df11['dates'] = pd.Timestamp('2023-06-03')

# %%
final = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], axis=0)

# %%
final
# Out:
#       Unnamed: 0                     R.N             FROM  \
# 0              1                     107           ASAPUR
# 1              2                     107           ASAPUR
# 2              3                     107           ASAPUR
# 3              4                     107           ASAPUR
# 4              5                     107           ASAPUR
# ...          ...                     ...              ...
# 1582        1583  Route No.\r\n(E105) FG  SADHU KI KUTIYA
# 1583        1584  Route No.\r\n(E105) FG  SADHU KI KUTIYA
# 1584        1585  Route No.\r\n(E105) FG        SAHABABAD
# 1585        1586  Route No.\r\n(E105) FG        SAHABABAD
# 1586        1587  Route No.\r\n(E105) FG        SAHABABAD
#
#                         TO  prs  revenue      dates
# 0        CANTT RLY STATION    3       66 2023-05-24
# 1     CANTT RLY\r\nSTATION    3       66 2023-05-24
# 2               DURGA KUND    1       27 2023-05-24
# 3                    LANKA    3       99 2023-05-24
# ...

# %%
final.replace("CANTT RLY\r\nSTATION", "CANTT RLY STATION", inplace=True)

# %%
final
# Out:
#       Unnamed: 0                     R.N             FROM  \
# 0              1                     107           ASAPUR
# 1              2                     107           ASAPUR
# 2              3                     107           ASAPUR
# 3              4                     107           ASAPUR
# 4              5                     107           ASAPUR
# ...          ...                     ...              ...
# 1582        1583  Route No.\r\n(E105) FG  SADHU KI KUTIYA
# 1583        1584  Route No.\r\n(E105) FG  SADHU KI KUTIYA
# 1584        1585  Route No.\r\n(E105) FG        SAHABABAD
# 1585        1586  Route No.\r\n(E105) FG        SAHABABAD
# 1586        1587  Route No.\r\n(E105) FG        SAHABABAD
#
#                        TO  prs  revenue      dates
# 0       CANTT RLY STATION    3       66 2023-05-24
# 1       CANTT RLY STATION    3       66 2023-05-24
# 2              DURGA KUND    1       27 2023-05-24
# 3                   LANKA    3       99 2023-05-24
# ...

# %%
final.replace("MIRZAMURAD\r\nBAZAR", "MIRZAMURAD BAZAR", inplace=True)

# %%
final
# Out:
#       Unnamed: 0                     R.N             FROM                 TO  \
# 0              1                     107           ASAPUR  CANTT RLY STATION
# 1              2                     107           ASAPUR  CANTT RLY STATION
# 2              3                     107           ASAPUR         DURGA KUND
# 3              4                     107           ASAPUR              LANKA
# 4              5                     107           ASAPUR        POLICE LINE
# ...          ...                     ...              ...                ...
# 1582        1583  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA
# 1583        1584  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA
# 1584        1585  Route No.\r\n(E105) FG        SAHABABAD             BOULIA
# 1585        1586  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR
# 1586        1587  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB
#
#       prs  revenue      dates
# ...

# %%
final[final["FROM"].str.contains("\r\n")]
# Out:
#       Unnamed: 0                     R.N                  FROM  \
# 24            25                     107  HAVELIYA\r\nCHAURAHA
# 25            26                     107  HAVELIYA\r\nCHAURAHA
# 26            27                     107  HAVELIYA\r\nCHAURAHA
# 114          115                 107(B)2  CHANDPUR\r\nCHAURAHA
# 115          116                 107(B)2  CHANDPUR\r\nCHAURAHA
# ...          ...                     ...                   ...
# 1476        1477  Route No.\r\n(E105) FG  CHANDPUR\r\nCHAURAHA
# 1477        1478  Route No.\r\n(E105) FG  CHANDPUR\r\nCHAURAHA
# 1478        1479  Route No.\r\n(E105) FG  CHANDPUR\r\nCHAURAHA
# 1479        1480  Route No.\r\n(E105) FG  CHANDPUR\r\nCHAURAHA
# 1480        1481  Route No.\r\n(E105) FG  CHANDPUR\r\nCHAURAHA
#
#                      TO  prs  revenue      dates
# 24    CANTT RLY STATION    1       22 2023-05-24
# 25                LANKA    1       33 2023-05-24
# 26         RAVINDERPURI    1       27 2023-05-24
# ...

# %%
final.replace("HAVELIYA\r\nCHAURAHA", "HAVELIYA CHAURAHA", inplace=True)
final.replace("CHANDPUR\r\nCHAURAHA", "CHANDPUR CHAURAHA", inplace=True)

# %%
final
# Out:
#       Unnamed: 0                     R.N             FROM                 TO  \
# 0              1                     107           ASAPUR  CANTT RLY STATION
# 1              2                     107           ASAPUR  CANTT RLY STATION
# 2              3                     107           ASAPUR         DURGA KUND
# 3              4                     107           ASAPUR              LANKA
# 4              5                     107           ASAPUR        POLICE LINE
# ...          ...                     ...              ...                ...
# 1582        1583  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA
# 1583        1584  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA
# 1584        1585  Route No.\r\n(E105) FG        SAHABABAD             BOULIA
# 1585        1586  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR
# 1586        1587  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB
#
#       prs  revenue      dates
# ...

# %%
final[final["FROM"].str.contains("\r\n")]
# Out:
#       Unnamed: 0          R.N                     FROM  \
# 152          153       109(A)       BHADAU\r\nCHOURAHA
# 185          186       109(A)  CITY RAILWAY\r\nSTATION
# 220          221       109(B)       BHADAU\r\nCHOURAHA
# 221          222       109(B)       BHADAU\r\nCHOURAHA
# 222          223       109(B)       BHADAU\r\nCHOURAHA
# ...          ...          ...                      ...
# 1390        1391  E110\r\n(B)    GIRJAGHAR\r\nCHAURAHA
# 1391        1392  E110\r\n(B)    GIRJAGHAR\r\nCHAURAHA
# 1413        1414  E110\r\n(C)    GIRJAGHAR\r\nCHAURAHA
# 1414        1415  E110\r\n(C)    GIRJAGHAR\r\nCHAURAHA
# 1415        1416  E110\r\n(C)    GIRJAGHAR\r\nCHAURAHA
#
#                            TO  prs  revenue      dates
# 152   CITY RAILWAY\r\nSTATION    1       12 2023-05-24
# 185         CANTT RLY STATION    3       36 2023-05-24
# 220         CANTT RLY STATION    1       17 2023-05-24
# 221                     LANKA    1       33 2023-05-24
# ...

# %%
final.replace("BHADAU\r\nCHOURAHA", "BHADAU CHOURAHA", inplace=True)
final.replace("CITY RAILWAY\r\nSTATION", "CITY RAILWAY STATION", inplace=True)
final.replace("GIRJAGHAR\r\nCHAURAHA", "GIRJAGHAR CHAURAHA", inplace=True)

# %%
final[final["FROM"].str.contains("\r\n")]
# Out:
#       Unnamed: 0          R.N                     FROM                 TO  \
# 300          301       111(A)  MIRZAMURAD E\r\nSTATION              LANKA
# 466          467         E101  MIRZAMURAD E\r\nSTATION  CANTT RLY STATION
# 467          468         E101  MIRZAMURAD E\r\nSTATION        KAAZI SARAI
# 468          469         E101  MIRZAMURAD E\r\nSTATION          KACHAHARI
# 527          528         E102     BABATPUR\r\nCHAURAHA        AGRASEN MOD
# ...          ...          ...                      ...                ...
# 1067        1068         E106     MARKANDEY\r\nMAHADEV         PURANA RTO
# 1068        1069         E106     MARKANDEY\r\nMAHADEV            ROHANIA
# 1289        1290  E107\r\n(A)        SARNATH\r\nMUSEAM  CANTT RLY STATION
# 1290        1291  E107\r\n(A)        SARNATH\r\nMUSEAM         MOHANSARAI
# 1291        1292  E107\r\n(A)        SARNATH\r\nMUSEAM           RAKHAUNA
#
#       prs  revenue      dates
# 300     1       48 2023-05-24
# ...

# %%
final.replace("MIRZAMURAD E\r\nSTATION", "MIRZAMURAD E STATION", inplace=True)
final.replace("MARKANDEY\r\nMAHADEV", "MARKANDEY MAHADEV", inplace=True)
final.replace("BABATPUR\r\nCHAURAHA", "BABATPUR CHAURAHA", inplace=True)
final.replace("SARNATH\r\nMUSEAM", "SARNATH MUSEAM", inplace=True)

# %%
final[final["FROM"].str.contains("\r\n")]
# Out:
#       Unnamed: 0                     R.N                 FROM  \
# 787          788                    E103    KACHHAWAN\r\nROAD
# 1182        1183                    E106  CHIRAIGAON\r\nBLOCK
# 1183        1184                    E106  CHIRAIGAON\r\nBLOCK
# 160          161                 107(B)2   SADHU KI\r\nKUTIYA
# 1137        1138                    E106  CHIRAIGAON\r\nBLOCK
# ...          ...                     ...                  ...
# 1654        1655  Route No.\r\n(E105) FG   SADHU KI\r\nKUTIYA
# 1655        1656  Route No.\r\n(E105) FG   SADHU KI\r\nKUTIYA
# 630          631                    E102  SANMUKH\r\nHOSPITAL
# 1004        1005                    E106  CHIRAIGAON\r\nBLOCK
# 1005        1006                    E106  CHIRAIGAON\r\nBLOCK
#
#                      TO  prs  revenue      dates
# 787   CANTT RLY STATION    2       96 2023-05-24
# 1182  CANTT RLY STATION    2       54 2023-05-24
# 1183            ROHANIA    1       38 2023-05-24
# ...

# %%
final.replace("KACHHAWAN\r\nROAD", "KACHHAWAN ROAD", inplace=True)
final.replace("CHIRAIGAON\r\nBLOCK", "CHIRAIGAON BLOCK", inplace=True)
final.replace("SADHU KI\r\nKUTIYA", "SADHU KI KUTIYA", inplace=True)
final.replace("SANMUKH\r\nHOSPITAL", "SANMUKH HOSPITAL", inplace=True)

# %%
final[final["FROM"].str.contains("\r\n")]
# Out:
#      Unnamed: 0     R.N                    FROM                 TO  prs  \
# 181         182  109(B)  BHIKARIPUR\r\nCROSSING  CANTT RLY STATION    3
# 182         183  109(B)  BHIKARIPUR\r\nCROSSING          RATHYATRA    1
# 230         231  109(B)  BHIKARIPUR\r\nCROSSING            RAJGHAT    1
# 170         171  109(B)  BHIKARIPUR\r\nCROSSING              LANKA    1
# 222         223  109(B)  BHIKARIPUR\r\nCROSSING              LANKA    1
# 175         176  109(B)  BHIKARIPUR\r\nCROSSING  CANTT RLY STATION    3
#
#      revenue      dates
# 181       51 2023-05-26
# 182       22 2023-05-26
# 230       33 2023-05-29
# 170       17 2023-05-30
# 222       17 2023-05-31
# 175       81 2023-06-02

# %%
final.replace("BHIKARIPUR\r\nCROSSING", "BHIKARIPUR CROSSING", inplace=True)

# %%
final[final["FROM"].str.contains("\r\n")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, R.N, FROM, TO, prs, revenue, dates]
# Index: []

# %%
final[final["TO"].str.contains("\r\n")]
# Out:
#       Unnamed: 0   R.N              FROM                 TO  prs  revenue  \
# 1179        1180  E106  MIRZAMURAD BAZAR  SWARVED\r\nMANDIR    1       54
#
#           dates
# 1179 2023-05-26

# %%
final.replace("SWARVED\r\nMANDIR", "SWARVED MANDIR", inplace=True)

# %%
final[final["TO"].str.contains("\r\n")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, R.N, FROM, TO, prs, revenue, dates]
# Index: []

# %%
fs = '../data/GTFS/stops.txt'
stops = pd.read_csv(fs)

# %%
stops
# Out:
#      stop_id  stop_code             stop_name  stop_desc   stop_lat  \
# 0          0        NaN  MIRZAMURAD E STATION        NaN  25.284666
# 1          1        NaN      MIRZAMURAD BAZAR        NaN  25.285235
# 2          2        NaN                   KIT        NaN  25.282433
# 3          3        NaN       SADHU KI KUTIYA        NaN  25.279853
# 4          4        NaN              RAKHAUNA        NaN  25.271908
# ..       ...        ...                   ...        ...        ...
# 120      120        NaN            TALIYABHAG        NaN  25.327688
# 121      121        NaN             MALDAHIYA        NaN  25.324263
# 122      122        NaN          KABIR CHAURA        NaN  25.319730
# 123      123        NaN              MAIDAGIN        NaN  25.318957
# 124      124        NaN             PILIKOTHI        NaN  25.326473
#
#       stop_lon  zone_id  stop_url  location_type  parent_station
# 0    82.780556      NaN       NaN            NaN             NaN
# ...

# %%
merged_df_from = pd.merge(final,stops,how='left',left_on='FROM',right_on='stop_name')

# %%
merged_df_from
# Out:
#        Unnamed: 0                     R.N             FROM                 TO  \
# 0               1                     107           ASAPUR  CANTT RLY STATION
# 1               2                     107           ASAPUR  CANTT RLY STATION
# 2               3                     107           ASAPUR         DURGA KUND
# 3               4                     107           ASAPUR              LANKA
# 4               5                     107           ASAPUR        POLICE LINE
# ...           ...                     ...              ...                ...
# 19052        1583  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA
# 19053        1584  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA
# 19054        1585  Route No.\r\n(E105) FG        SAHABABAD             BOULIA
# 19055        1586  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR
# 19056        1587  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB
#
# ...

# %%
A1= merged_df_from.drop(['Unnamed: 0', 'stop_id', 'stop_code', 'stop_name', 'stop_desc', 'zone_id', 'stop_url', 'location_type', 'parent_station'], axis=1)

# %%
A1
# Out:
#                           R.N             FROM                 TO  prs  \
# 0                         107           ASAPUR  CANTT RLY STATION    3
# 1                         107           ASAPUR  CANTT RLY STATION    3
# 2                         107           ASAPUR         DURGA KUND    1
# 3                         107           ASAPUR              LANKA    3
# 4                         107           ASAPUR        POLICE LINE    4
# ...                       ...              ...                ...  ...
# 19052  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA    1
# 19053  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA    1
# 19054  Route No.\r\n(E105) FG        SAHABABAD             BOULIA    1
# 19055  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR    2
# 19056  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB    1
#
#        revenue      dates   stop_lat   stop_lon
# 0           66 2023-05-24  25.360452  83.023231
# ...

# %%
A1.rename(columns={'stop_lat':'FROM_LAT', 'stop_lon':'FROM_LON'}, inplace=True)
A1
# Out:
#                           R.N             FROM                 TO  prs  \
# 0                         107           ASAPUR  CANTT RLY STATION    3
# 1                         107           ASAPUR  CANTT RLY STATION    3
# 2                         107           ASAPUR         DURGA KUND    1
# 3                         107           ASAPUR              LANKA    3
# 4                         107           ASAPUR        POLICE LINE    4
# ...                       ...              ...                ...  ...
# 19052  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA    1
# 19053  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA    1
# 19054  Route No.\r\n(E105) FG        SAHABABAD             BOULIA    1
# 19055  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR    2
# 19056  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB    1
#
#        revenue      dates   FROM_LAT   FROM_LON
# 0           66 2023-05-24  25.360452  83.023231
# ...

# %%
A2 = merged_df_to = pd.merge(final,stops,how='left',left_on='TO',right_on='stop_name')
print(A2)
# Out:
#        Unnamed: 0                     R.N             FROM                 TO  \
# 0               1                     107           ASAPUR  CANTT RLY STATION
# 1               2                     107           ASAPUR  CANTT RLY STATION
# 2               3                     107           ASAPUR         DURGA KUND
# 3               4                     107           ASAPUR              LANKA
# 4               5                     107           ASAPUR        POLICE LINE
# ...           ...                     ...              ...                ...
# 19052        1583  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA
# 19053        1584  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA
# 19054        1585  Route No.\r\n(E105) FG        SAHABABAD             BOULIA
# 19055        1586  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR
# 19056        1587  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB
#
# ...

# %%
B2 = A2.drop(['Unnamed: 0', 'R.N', 'prs', 'revenue', 'FROM', 'TO', 'stop_id', 'stop_code', 'stop_name', 'stop_desc', 'zone_id', 'stop_url', 'location_type', 'parent_station', 'dates'], axis=1)

# %%
B2.rename(columns={"stop_lat":'TO_LAT', 'stop_lon':'TO_LON'}, inplace=True)
result = pd.concat([A1,B2], axis=1)

# %%
result
# Out:
#                           R.N             FROM                 TO  prs  \
# 0                         107           ASAPUR  CANTT RLY STATION    3
# 1                         107           ASAPUR  CANTT RLY STATION    3
# 2                         107           ASAPUR         DURGA KUND    1
# 3                         107           ASAPUR              LANKA    3
# 4                         107           ASAPUR        POLICE LINE    4
# ...                       ...              ...                ...  ...
# 19052  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA    1
# 19053  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA    1
# 19054  Route No.\r\n(E105) FG        SAHABABAD             BOULIA    1
# 19055  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR    2
# 19056  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB    1
#
#        revenue      dates   FROM_LAT   FROM_LON     TO_LAT     TO_LON
# ...

# %%
# %pip install geopandas
import geopandas as gpd
import json
import requests
import numpy as np
# %pip install shapely
from shapely.geometry import Point
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dell\anaconda3\lib\site-packages)
# ...

# %%
def traveltimeTransit(latHome, lonHome,latWork,lonWork, time)->int:
    request= "http://localhost:8080/otp/routers/default/plan?fromPlace="+str(latHome)\
    + ","+str(lonHome)+"&toPlace="+str(latWork) + ","+str(lonWork)+ "&"+"&mode=WALK,TRANSIT&date=05-01-2022&time="\
    +time+"&maxWalkDistance=750"
    # print(request)
    r = requests.get(request)
    data=r.json()
    if 'plan' in data.keys() and 'itineraries' in data['plan'].keys():
        return int(data['plan']['itineraries'][0]['duration'])
    else:
        return np.nan

# %%
def traveltimeDrive(latHome, lonHome,latWork,lonWork, time)->int:
    request= "http://localhost:8080/otp/routers/default/plan?fromPlace="+str(latHome)\
    + ","+str(lonHome)+"&toPlace="+str(latWork) + ","+str(lonWork)+ "&"+"&mode=WALK,CAR&date=05-01-2021&time="\
    +time+"&maxWalkDistance=750"
    r = requests.get(request)
    data=r.json()
    # print(data['plan'])
    if 'plan' in data.keys() and 'itineraries' in data['plan'].keys():
        return int(data['plan']['itineraries'][0]['duration'])
    else:
        return np.nan

# %%
result['travel_time_transit_1PM']=np.nan
for i,row in result.iterrows():
    result.loc[i,'travel_time_transit_1PM']=traveltimeTransit(result.loc[i,'FROM_LAT'],result.loc[i,'FROM_LON'],result.loc[i,'TO_LAT'],result.loc[i,'TO_LON'],"1:00PM")

# %%
result
# Out:
#                           R.N             FROM                 TO  prs  \
# 0                         107           ASAPUR  CANTT RLY STATION    3
# 1                         107           ASAPUR  CANTT RLY STATION    3
# 2                         107           ASAPUR         DURGA KUND    1
# 3                         107           ASAPUR              LANKA    3
# 4                         107           ASAPUR        POLICE LINE    4
# ...                       ...              ...                ...  ...
# 19052  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA    1
# 19053  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA    1
# 19054  Route No.\r\n(E105) FG        SAHABABAD             BOULIA    1
# 19055  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR    2
# 19056  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB    1
#
#        revenue      dates   FROM_LAT   FROM_LON     TO_LAT     TO_LON  \
# ...

# %%
result['travel_time_transit_9AM']=np.nan
for i,row in result.iterrows():
    result.loc[i,'travel_time_transit_9AM']=traveltimeTransit(result.loc[i,'FROM_LAT'],result.loc[i,'FROM_LON'],result.loc[i,'TO_LAT'],result.loc[i,'TO_LON'],"9:00AM")

# %%
result
# Out:
#                           R.N             FROM                 TO  prs  \
# 0                         107           ASAPUR  CANTT RLY STATION    3
# 1                         107           ASAPUR  CANTT RLY STATION    3
# 2                         107           ASAPUR         DURGA KUND    1
# 3                         107           ASAPUR              LANKA    3
# 4                         107           ASAPUR        POLICE LINE    4
# ...                       ...              ...                ...  ...
# 19052  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA    1
# 19053  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA    1
# 19054  Route No.\r\n(E105) FG        SAHABABAD             BOULIA    1
# 19055  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR    2
# 19056  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB    1
#
#        revenue      dates   FROM_LAT   FROM_LON     TO_LAT     TO_LON  \
# ...

# %%
result['travel_time_transit_9AM']=np.nan
result['travel_time_transit_4PM']=np.nan
result['travel_trime_Drive_9AM']=np.nan
result['travel_trime_Drive_1PM']=np.nan
result['travel_trime_Drive_4PM']=np.nan


for i,row in result.iterrows():
    result.loc[i,'travel_time_transit_9AM']=traveltimeTransit(result.loc[i,'FROM_LAT'],result.loc[i,'FROM_LON'],result.loc[i,'TO_LAT'],result.loc[i,'TO_LON'],"9:00AM")
    result.loc[i,'travel_time_transit_4PM']=traveltimeTransit(result.loc[i,'FROM_LAT'],result.loc[i,'FROM_LON'],result.loc[i,'TO_LAT'],result.loc[i,'TO_LON'],"4:00PM")
    result.loc[i,'travel_time_Drive_9AM']=traveltimeDrive(result.loc[i,'FROM_LAT'],result.loc[i,'FROM_LON'],result.loc[i,'TO_LAT'],result.loc[i,'TO_LON'],"9:00AM")
    result.loc[i,'travel_time_Drive_1PM']=traveltimeDrive(result.loc[i,'FROM_LAT'],result.loc[i,'FROM_LON'],result.loc[i,'TO_LAT'],result.loc[i,'TO_LON'],"1:00PM")
    result.loc[i,'travel_time_Drive_4PM']=traveltimeDrive(result.loc[i,'FROM_LAT'],result.loc[i,'FROM_LON'],result.loc[i,'TO_LAT'],result.loc[i,'TO_LON'],"4:00PM")

# %%
result
# Out:
#                           R.N             FROM                 TO  prs  \
# 0                         107           ASAPUR  CANTT RLY STATION    3
# 1                         107           ASAPUR  CANTT RLY STATION    3
# 2                         107           ASAPUR         DURGA KUND    1
# 3                         107           ASAPUR              LANKA    3
# 4                         107           ASAPUR        POLICE LINE    4
# ...                       ...              ...                ...  ...
# 19052  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA    1
# 19053  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA    1
# 19054  Route No.\r\n(E105) FG        SAHABABAD             BOULIA    1
# 19055  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR    2
# 19056  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB    1
#
#        revenue      dates   FROM_LAT   FROM_LON     TO_LAT     TO_LON  \
# ...

# %%
result1 = result.drop(['travel_trime_Drive_9AM','travel_trime_Drive_1PM','travel_trime_Drive_4PM' ], axis=1)

# %%
result1
# Out:
#                           R.N             FROM                 TO  prs  \
# 0                         107           ASAPUR  CANTT RLY STATION    3
# 1                         107           ASAPUR  CANTT RLY STATION    3
# 2                         107           ASAPUR         DURGA KUND    1
# 3                         107           ASAPUR              LANKA    3
# 4                         107           ASAPUR        POLICE LINE    4
# ...                       ...              ...                ...  ...
# 19052  Route No.\r\n(E105) FG  SADHU KI KUTIYA          DHARSAUNA    1
# 19053  Route No.\r\n(E105) FG  SADHU KI KUTIYA           MODHAILA    1
# 19054  Route No.\r\n(E105) FG        SAHABABAD             BOULIA    1
# 19055  Route No.\r\n(E105) FG        SAHABABAD   MIRZAMURAD BAZAR    2
# 19056  Route No.\r\n(E105) FG        SAHABABAD          RAJATALAB    1
#
#        revenue      dates   FROM_LAT   FROM_LON     TO_LAT     TO_LON  \
# ...

# %%
import pandas as pd
import numpy as np
ropeway = pd.read_csv('O_D_PAIR_ROPEWAY.csv')

# %%
ropeway
# Out:
#     Route Number                   From                     To    PRS  \
# 0              1  Cantt Railway Station    Girja Ghar Chauraha  19598
# 1              1    Girja Ghar Chauraha  Cantt Railway Station  44796
# 2              1  Cantt Railway Station     Rathyatra Crossing   1900
# 3              1     Rathyatra Crossing  Cantt Railway Station   1476
# 4              1    Girja Ghar Chauraha          Sajan Choraha   5755
# 5              1          Sajan Choraha    Girja Ghar Chauraha   5249
# 6              1    Girja Ghar Chauraha     Rathyatra Crossing   7247
# 7              1     Rathyatra Crossing          Sajan Choraha    175
# 8              1          Sajan Choraha  Cantt Railway Station     52
# 9              1  Cantt Railway Station          Sajan Choraha      0
# 10             1          Sajan Choraha     Rathyatra Crossing    477
# 11             1     Rathyatra Crossing    Girja Ghar Chauraha  16222
#
#      FROM_LAT   FROM_LON     TO_LAT     TO_LON
# ...

# %%
def traveltimeGondola(latHome, lonHome,latWork,lonWork, time)->int:
    request= "http://localhost:8080/otp/routers/default/plan?fromPlace="+str(latHome)\
    + ","+str(lonHome)+"&toPlace="+str(latWork) + ","+str(lonWork)+ "&"+"&mode=WALK,GONDOLA&date=05-01-2021&time="\
    +time+"&maxWalkDistance=750"
    r = requests.get(request)
    data=r.json()
    # print(data['plan'])
    if 'plan' in data.keys() and 'itineraries' in data['plan'].keys():
        return int(data['plan']['itineraries'][0]['duration'])
    else:
        return np.nan

# %%
ropeway['travel_time_gondola_9AM']=np.nan
ropeway['travel_time_gondola_1PM']=np.nan
ropeway['travel_time_gondola_4PM']=np.nan

for i,row in ropeway.iterrows():
    ropeway.loc[i,'travel_time_gondola_9AM']=traveltimeGondola(ropeway.loc[i,'FROM_LAT'],ropeway.loc[i,'FROM_LON'],ropeway.loc[i,'TO_LAT'],ropeway.loc[i,'TO_LON'],"9:00AM")
    ropeway.loc[i,'travel_time_gondola_1PM']=traveltimeGondola(ropeway.loc[i,'FROM_LAT'],ropeway.loc[i,'FROM_LON'],ropeway.loc[i,'TO_LAT'],ropeway.loc[i,'TO_LON'],"1:00PM")
    ropeway.loc[i,'travel_time_gondola_4PM']=traveltimeGondola(ropeway.loc[i,'FROM_LAT'],ropeway.loc[i,'FROM_LON'],ropeway.loc[i,'TO_LAT'],ropeway.loc[i,'TO_LON'],"4:00PM")

# %%
ropeway
# Out:
#     Route Number                   From                     To    PRS  \
# 0              1  Cantt Railway Station    Girja Ghar Chauraha  19598
# 1              1    Girja Ghar Chauraha  Cantt Railway Station  44796
# 2              1  Cantt Railway Station     Rathyatra Crossing   1900
# 3              1     Rathyatra Crossing  Cantt Railway Station   1476
# 4              1    Girja Ghar Chauraha          Sajan Choraha   5755
# 5              1          Sajan Choraha    Girja Ghar Chauraha   5249
# 6              1    Girja Ghar Chauraha     Rathyatra Crossing   7247
# 7              1     Rathyatra Crossing          Sajan Choraha    175
# 8              1          Sajan Choraha  Cantt Railway Station     52
# 9              1  Cantt Railway Station          Sajan Choraha      0
# 10             1          Sajan Choraha     Rathyatra Crossing    477
# 11             1     Rathyatra Crossing    Girja Ghar Chauraha  16222
#
# ...
